# %%
import sys
sys.path.append("..")
import nest_asyncio
nest_asyncio.apply()

# %%
from factcheck import FactCheck
# Out:
# False

# %%
from factcheck.utils.utils import load_yaml
api_config_path="../api_config.yaml"
api_config = load_yaml(api_config_path)


factcheck_instance = FactCheck(
        default_model="gpt-4o-eastus", client=None, api_config=api_config, prompt="chatgpt_prompt", retriever="serper"
    )
# Out:
# [INFO]2025-01-22 08:01:28,638 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 08:01:28,645 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 08:01:28,652 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 08:01:28,658 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 08:01:28,664 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 08:01:28,672 __init__.py:76: ===Sub-modules Init Finished===
# == Init decompose_model with model: gpt-4o-eastus
# == Init checkworthy_model with model: gpt-4o-eastus
# == Init query_generator_model with model: gpt-4o-eastus
# == Init evidence_retrieval_model with model: gpt-4o-eastus
# == Init claim_verify_model with model: gpt-4o-eastus

# %%
# Example text
text = "Climate change refers to long-term changes in temperature and weather patterns, primarily caused by human activities like burning fossil fuels and deforestation. These actions release greenhouse gases, which trap heat in the atmosphere. As for cows, they produce methane, a potent greenhouse gas, during digestion. So, while they can't literally talk, they do play a role in climate change!"

# Run the fact-check pipeline
results = factcheck_instance.check_text(text)
# Out:
# [ERROR]2025-01-22 08:01:36,576 Decompose.py:135: Parse LLM response error Restore claims not satisfied., response is: {
#     "Climate change refers to long-term changes in temperature and weather patterns.": "Climate change refers to long-term changes in temperature and weather patterns,",
#     "Climate change is primarily caused by human activities like burning fossil fuels and deforestation.": "primarily caused by human activities like burning fossil fuels and deforestation.",
#     "Burning fossil fuels releases greenhouse gases.": "burning fossil fuels",
#     "Deforestation releases greenhouse gases.": "and deforestation.",
#     "Greenhouse gases trap heat in the atmosphere.": "These actions release greenhouse gases, which trap heat in the atmosphere.",
#     "Cows produce methane during digestion.": "As for cows, they produce methane, a potent greenhouse gas, during digestion.",
#     "Methane is a potent greenhouse gas.": "a potent greenhouse gas,",
#     "Cows play a role in climate change.": "So, while they can't literally talk, they do play a role in climate change!"
# }
# [ERROR]2025-01-22 08:01:36,577 Decompose.py:136: Parse LLM response error, prompt is: [[{'role': 'system', 'content': 'You are a helpful assistant designed to output JSON.'}, {'role': 'user', 'content': 'Given a text and a list of facts derived from the text, your task is to split the text into chunks that derive each fact.\nFor each fact, please find the corresponding continues span in the original text that contains the information to derive the fact. The answer should be a JSON dict where the keys are the facts and the values are the corresponding spans copied from the original text.\nPlease make sure the returned spans can be concatenated to the full original doc.\n\nFor example,\nText: Mary is a five-year old girl, she likes playing piano and she doesn\'t like cookies.\nFacts: ["Mary is a five-year old girl.", "Mary likes playing piano.", "Mary doesn\'t like cookies."]\n\nOutput:\n{"Mary is a five-year old girl.":"Mary is a five-year old girl,",\n"Mary likes playing piano.":"she likes playing piano",\n"Mary doesn\'t like cookies.":"and she doesn\'t like cookies."]\n\nText: Climate change refers to long-term changes in temperature and weather patterns, primarily caused by human activities like burning fossil fuels and deforestation. These actions release greenhouse gases, which trap heat in the atmosphere. As for cows, they produce methane, a potent greenhouse gas, during digestion. So, while they can\'t literally talk, they do play a role in climate change!\nFacts: [\'Climate change refers to long-term changes in temperature and weather patterns.\', \'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.\', \'Burning fossil fuels releases greenhouse gases.\', \'Deforestation releases greenhouse gases.\', \'Greenhouse gases trap heat in the atmosphere.\', \'Cows produce methane during digestion.\', \'Methane is a potent greenhouse gas.\', \'Cows play a role in climate change.\']\nOutput:'}]]
# [ERROR]2025-01-22 08:01:38,780 Decompose.py:135: Parse LLM response error Restore claims not satisfied., response is: {
#     "Climate change refers to long-term changes in temperature and weather patterns.": "Climate change refers to long-term changes in temperature and weather patterns,",
#     "Climate change is primarily caused by human activities like burning fossil fuels and deforestation.": "primarily caused by human activities like burning fossil fuels and deforestation.",
#     "Burning fossil fuels releases greenhouse gases.": "burning fossil fuels",
#     "Deforestation releases greenhouse gases.": "and deforestation.",
#     "Greenhouse gases trap heat in the atmosphere.": "These actions release greenhouse gases, which trap heat in the atmosphere.",
#     "Cows produce methane during digestion.": "As for cows, they produce methane, a potent greenhouse gas, during digestion.",
#     "Methane is a potent greenhouse gas.": "they produce methane, a potent greenhouse gas,",
#     "Cows play a role in climate change.": "So, while they can't literally talk, they do play a role in climate change!"
# }
# [ERROR]2025-01-22 08:01:38,781 Decompose.py:136: Parse LLM response error, prompt is: [[{'role': 'system', 'content': 'You are a helpful assistant designed to output JSON.'}, {'role': 'user', 'content': 'Given a text and a list of facts derived from the text, your task is to split the text into chunks that derive each fact.\nFor each fact, please find the corresponding continues span in the original text that contains the information to derive the fact. The answer should be a JSON dict where the keys are the facts and the values are the corresponding spans copied from the original text.\nPlease make sure the returned spans can be concatenated to the full original doc.\n\nFor example,\nText: Mary is a five-year old girl, she likes playing piano and she doesn\'t like cookies.\nFacts: ["Mary is a five-year old girl.", "Mary likes playing piano.", "Mary doesn\'t like cookies."]\n\nOutput:\n{"Mary is a five-year old girl.":"Mary is a five-year old girl,",\n"Mary likes playing piano.":"she likes playing piano",\n"Mary doesn\'t like cookies.":"and she doesn\'t like cookies."]\n\nText: Climate change refers to long-term changes in temperature and weather patterns, primarily caused by human activities like burning fossil fuels and deforestation. These actions release greenhouse gases, which trap heat in the atmosphere. As for cows, they produce methane, a potent greenhouse gas, during digestion. So, while they can\'t literally talk, they do play a role in climate change!\nFacts: [\'Climate change refers to long-term changes in temperature and weather patterns.\', \'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.\', \'Burning fossil fuels releases greenhouse gases.\', \'Deforestation releases greenhouse gases.\', \'Greenhouse gases trap heat in the atmosphere.\', \'Cows produce methane during digestion.\', \'Methane is a potent greenhouse gas.\', \'Cows play a role in climate change.\']\nOutput:'}]]
# [ERROR]2025-01-22 08:01:42,080 Decompose.py:135: Parse LLM response error Restore claims not satisfied., response is: {
#   "Climate change refers to long-term changes in temperature and weather patterns.": "Climate change refers to long-term changes in temperature and weather patterns,",
#   "Climate change is primarily caused by human activities like burning fossil fuels and deforestation.": "primarily caused by human activities like burning fossil fuels and deforestation.",
#   "Burning fossil fuels releases greenhouse gases.": "These actions release greenhouse gases,",
#   "Deforestation releases greenhouse gases.": "These actions release greenhouse gases,",
#   "Greenhouse gases trap heat in the atmosphere.": "which trap heat in the atmosphere.",
#   "Cows produce methane during digestion.": "As for cows, they produce methane, a potent greenhouse gas, during digestion.",
#   "Methane is a potent greenhouse gas.": "they produce methane, a potent greenhouse gas, during digestion.",
#   "Cows play a role in climate change.": "So, while they can't literally talk, they do play a role in climate change!"
# }
# [ERROR]2025-01-22 08:01:42,082 Decompose.py:136: Parse LLM response error, prompt is: [[{'role': 'system', 'content': 'You are a helpful assistant designed to output JSON.'}, {'role': 'user', 'content': 'Given a text and a list of facts derived from the text, your task is to split the text into chunks that derive each fact.\nFor each fact, please find the corresponding continues span in the original text that contains the information to derive the fact. The answer should be a JSON dict where the keys are the facts and the values are the corresponding spans copied from the original text.\nPlease make sure the returned spans can be concatenated to the full original doc.\n\nFor example,\nText: Mary is a five-year old girl, she likes playing piano and she doesn\'t like cookies.\nFacts: ["Mary is a five-year old girl.", "Mary likes playing piano.", "Mary doesn\'t like cookies."]\n\nOutput:\n{"Mary is a five-year old girl.":"Mary is a five-year old girl,",\n"Mary likes playing piano.":"she likes playing piano",\n"Mary doesn\'t like cookies.":"and she doesn\'t like cookies."]\n\nText: Climate change refers to long-term changes in temperature and weather patterns, primarily caused by human activities like burning fossil fuels and deforestation. These actions release greenhouse gases, which trap heat in the atmosphere. As for cows, they produce methane, a potent greenhouse gas, during digestion. So, while they can\'t literally talk, they do play a role in climate change!\nFacts: [\'Climate change refers to long-term changes in temperature and weather patterns.\', \'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.\', \'Burning fossil fuels releases greenhouse gases.\', \'Deforestation releases greenhouse gases.\', \'Greenhouse gases trap heat in the atmosphere.\', \'Cows produce methane during digestion.\', \'Methane is a potent greenhouse gas.\', \'Cows play a role in climate change.\']\nOutput:'}]]
# [INFO]2025-01-22 08:01:42,083 __init__.py:110: == raw_text claims 0 --- Climate change refers to long-term changes in temperature and weather patterns. --- {'text': 'Climate change refers to long-term changes in temperature and weather patterns,', 'start': 0, 'end': 79}
# [INFO]2025-01-22 08:01:42,084 __init__.py:110: == raw_text claims 1 --- Climate change is primarily caused by human activities like burning fossil fuels and deforestation. --- {'text': 'primarily caused by human activities like burning fossil fuels and deforestation.', 'start': 80, 'end': 161}
# [INFO]2025-01-22 08:01:42,084 __init__.py:110: == raw_text claims 2 --- Burning fossil fuels releases greenhouse gases. --- {'text': 'These actions release greenhouse gases,', 'start': 162, 'end': 201}
# [INFO]2025-01-22 08:01:42,086 __init__.py:110: == raw_text claims 3 --- Deforestation releases greenhouse gases. --- {'text': '', 'start': 201, 'end': 201}
# [INFO]2025-01-22 08:01:42,086 __init__.py:110: == raw_text claims 4 --- Greenhouse gases trap heat in the atmosphere. --- {'text': 'which trap heat in the atmosphere.', 'start': 202, 'end': 236}
# [INFO]2025-01-22 08:01:42,087 __init__.py:110: == raw_text claims 5 --- Cows produce methane during digestion. --- {'text': 'As for cows, they produce methane, a potent greenhouse gas, during digestion.', 'start': 237, 'end': 314}
# [INFO]2025-01-22 08:01:42,088 __init__.py:110: == raw_text claims 6 --- Methane is a potent greenhouse gas. --- {'text': '', 'start': 314, 'end': 314}
# [INFO]2025-01-22 08:01:42,089 __init__.py:110: == raw_text claims 7 --- Cows play a role in climate change. --- {'text': "So, while they can't literally talk, they do play a role in climate change!", 'start': 315, 'end': 390}
# [INFO]2025-01-22 08:01:42,089 __init__.py:112: == Checkworthy claims 0: Climate change refers to long-term changes in temperature and weather patterns.
# [INFO]2025-01-22 08:01:42,090 __init__.py:112: == Checkworthy claims 1: Climate change is primarily caused by human activities like burning fossil fuels and deforestation.
# [INFO]2025-01-22 08:01:42,091 __init__.py:112: == Checkworthy claims 2: Burning fossil fuels releases greenhouse gases.
# [INFO]2025-01-22 08:01:42,092 __init__.py:112: == Checkworthy claims 3: Deforestation releases greenhouse gases.
# [INFO]2025-01-22 08:01:42,092 __init__.py:112: == Checkworthy claims 4: Greenhouse gases trap heat in the atmosphere.
# [INFO]2025-01-22 08:01:42,093 __init__.py:112: == Checkworthy claims 5: Cows produce methane during digestion.
# [INFO]2025-01-22 08:01:42,094 __init__.py:112: == Checkworthy claims 6: Methane is a potent greenhouse gas.
# [INFO]2025-01-22 08:01:42,095 __init__.py:112: == Checkworthy claims 7: Cows play a role in climate change.
# [INFO]2025-01-22 08:01:42,095 __init__.py:118: == Claim: Climate change refers to long-term changes in temperature and weather patterns. --- Queries: ['Climate change refers to long-term changes in temperature and weather patterns.', 'What does climate change refer to?', 'What types of changes are included in climate change?']
# [INFO]2025-01-22 08:01:42,096 __init__.py:118: == Claim: Climate change is primarily caused by human activities like burning fossil fuels and deforestation. --- Queries: ['Climate change is primarily caused by human activities like burning fossil fuels and deforestation.', 'What are the primary causes of climate change?', 'How do human activities contribute to climate change?', 'What is the impact of burning fossil fuels on climate change?', 'How does deforestation affect climate change?']
# [INFO]2025-01-22 08:01:42,097 __init__.py:118: == Claim: Burning fossil fuels releases greenhouse gases. --- Queries: ['Burning fossil fuels releases greenhouse gases.', 'What happens when fossil fuels are burned?', 'Do burning fossil fuels release greenhouse gases?']
# [INFO]2025-01-22 08:01:42,097 __init__.py:118: == Claim: Deforestation releases greenhouse gases. --- Queries: ['Deforestation releases greenhouse gases.', 'Does deforestation release greenhouse gases?']
# [INFO]2025-01-22 08:01:42,098 __init__.py:118: == Claim: Greenhouse gases trap heat in the atmosphere. --- Queries: ['Greenhouse gases trap heat in the atmosphere.', 'What do greenhouse gases do?', 'Where do greenhouse gases trap heat?']
# [INFO]2025-01-22 08:01:42,099 __init__.py:118: == Claim: Cows produce methane during digestion. --- Queries: ['Cows produce methane during digestion.', 'Do cows produce methane during digestion?']
# [INFO]2025-01-22 08:01:42,100 __init__.py:118: == Claim: Methane is a potent greenhouse gas. --- Queries: ['Methane is a potent greenhouse gas.', 'Is methane a greenhouse gas?', 'How potent is methane as a greenhouse gas compared to others?']
# [INFO]2025-01-22 08:01:42,100 __init__.py:118: == Claim: Cows play a role in climate change. --- Queries: ['Cows play a role in climate change.', 'Do cows play a role in climate change? If so, how?']
# [INFO]2025-01-22 08:01:42,101 serper_retriever.py:31: Collecting evidences ...
# [INFO]2025-01-22 08:01:44,023 serper_retriever.py:44: Collect evidences done!
# [INFO]2025-01-22 08:01:44,023 __init__.py:126: == Claim: Climate change refers to long-term changes in temperature and weather patterns.
# [INFO]2025-01-22 08:01:44,024 __init__.py:127: == Evidence: [{'text': 'Climate change refers to long-term changes in temperature and weather patterns.\nAnswer: Climate change refers to long-term shifts in temperatures and weather patterns. Human activities have been the main driver of climate change, primarily due to the burning of fossil fuels like coal, oil and gas.', 'url': 'Google Answer Box'}, {'text': "What does climate change refer to?\nAnswer: Climate change describes a change in the average conditions — such as temperature and rainfall — in a region over a long period of time. NASA scientists have observed Earth's surface is warming, and many of the warmest years on record have happened in the past 20 years.", 'url': 'Google Answer Box'}, {'text': 'What types of changes are included in climate change?\nAnswer: Multiple lines of evidence show changes in our weather, oceans, and ecosystems, such as:\n___Changing temperature and precipitation patterns. ...\n___Increases in ocean temperatures, sea level, and acidity. ...\n___Melting of glaciers and sea ice. ...\n___Changes in the frequency, intensity, and duration of extreme weather events.', 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,025 __init__.py:126: == Claim: Climate change is primarily caused by human activities like burning fossil fuels and deforestation.
# [INFO]2025-01-22 08:01:44,026 __init__.py:127: == Evidence: [{'text': "Climate change is primarily caused by human activities like burning fossil fuels and deforestation.\nAnswer: Burning fossil fuels, cutting down forests and farming livestock are increasingly influencing the climate and the earth's temperature. This adds enormous amounts of greenhouse gases to those naturally occurring in the atmosphere, increasing the greenhouse effect and global warming.", 'url': 'Google Answer Box'}, {'text': "What are the primary causes of climate change?\nAnswer: Fossil fuels – coal, oil and gas – are by far the largest contributor to global climate change, accounting for over 75 per cent of global greenhouse gas emissions and nearly 90 per cent of all carbon dioxide emissions. As greenhouse gas emissions blanket the Earth, they trap the sun's heat.", 'url': 'Google Answer Box'}, {'text': "How do human activities contribute to climate change?\nAnswer: Burning fossil fuels, cutting down forests and farming livestock are increasingly influencing the climate and the earth's temperature. This adds enormous amounts of greenhouse gases to those naturally occurring in the atmosphere, increasing the greenhouse effect and global warming.", 'url': 'Google Answer Box'}, {'text': 'What is the impact of burning fossil fuels on climate change?\nAnswer: What is the link between fossil fuels and climate change? When fossil fuels are burned, they release large amounts of carbon dioxide, a greenhouse gas, into the air. Greenhouse gases trap heat in our atmosphere, causing global warming. Already the average global temperature has increased by 1C.', 'url': 'Google Answer Box'}, {'text': "How does deforestation affect climate change?\nAnswer: Trees not only absorb carbon dioxide from our air, they also store carbon in their roots, leaves and trunk. Trees in the Amazon rainforest hold 48 billion tons of carbon. So, when trees are cut down, it's a double whammy on climate change—more carbon dioxide is released and less is absorbed.", 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,026 __init__.py:126: == Claim: Burning fossil fuels releases greenhouse gases.
# [INFO]2025-01-22 08:01:44,027 __init__.py:127: == Evidence: [{'text': 'Burning fossil fuels releases greenhouse gases.\nAnswer: When fossil fuels are burned, they release large amounts of carbon dioxide, a greenhouse gas, into the air. Greenhouse gases trap heat in our atmosphere, causing global warming. Already the average global temperature has increased by 1C.', 'url': 'Google Answer Box'}, {'text': 'What happens when fossil fuels are burned?\nAnswer: When fossil fuels are burned, they release nitrogen oxides into the atmosphere, which contribute to the formation of smog and acid rain. The most common nitrogen-related compounds emitted into the air by human activities are collectively referred to as nitrogen oxides.', 'url': 'Google Answer Box'}, {'text': 'Do burning fossil fuels release greenhouse gases?\nAnswer: Human activities are responsible for almost all of the increase in greenhouse gases in the atmosphere over the last 150 years. The largest source of greenhouse gas emissions from human activities in the United States is from burning fossil fuels for electricity, heat, and transportation.', 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,027 __init__.py:126: == Claim: Deforestation releases greenhouse gases.
# [INFO]2025-01-22 08:01:44,028 __init__.py:127: == Evidence: [{'text': 'Deforestation releases greenhouse gases.\nAnswer: When deforestation occurs, much of the carbon stored by trees\ufeff is released back into the atmosphere as carbon dioxide, which contributes to climate change\ufeff.', 'url': 'Google Answer Box'}, {'text': 'Does deforestation release greenhouse gases?\nAnswer: If forests are cleared, or even disturbed, they release carbon dioxide and other greenhouse gases. Forest loss and damage is the cause of around 10% of global warming.', 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,029 __init__.py:126: == Claim: Greenhouse gases trap heat in the atmosphere.
# [INFO]2025-01-22 08:01:44,029 __init__.py:127: == Evidence: [{'text': 'Greenhouse gases trap heat in the atmosphere.\nAnswer: The greenhouse effect works much the same way on Earth. Gases in the atmosphere, such as carbon dioxide, trap heat similar to the glass roof of a greenhouse. These heat-trapping gases are called greenhouse gases. During the day, the Sun shines through the atmosphere.', 'url': 'Google Answer Box'}, {'text': "What do greenhouse gases do?\nAnswer: Greenhouse gases act similarly to the glass in a greenhouse: they absorb the sun's heat that radiates from the Earth's surface, trap it in the atmosphere and prevent it from escaping into space. The greenhouse effect keeps the Earth's temperature warmer than it would otherwise be, supporting life on Earth.", 'url': 'Google Answer Box'}, {'text': "Where do greenhouse gases trap heat?\nAnswer: Earth's greenhouse gases trap heat in the atmosphere and warm the planet. The main gases responsible for the greenhouse effect include carbon dioxide, methane, nitrous oxide, and water vapor.", 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,030 __init__.py:126: == Claim: Cows produce methane during digestion.
# [INFO]2025-01-22 08:01:44,030 __init__.py:127: == Evidence: [{'text': 'Cows produce methane during digestion.\nAnswer: Methane is the main greenhouse gas produced in grazing systems. Ruminant livestock (cattle, sheep, and goats) have microbes in their rumen called methanogens. These microbes produce methane (from the fermentation of feed) that is then belched out.', 'url': 'Google Answer Box'}, {'text': 'Do cows produce methane during digestion?\nAnswer: Methane emissions from the digestive processes in ruminant animals, including cattle, sheep and wild animals, is estimated to provide an atmospheric source of 87-94 Tg (a million million grams) per year. Methane emissions depend upon the number and type of animals and the type of food.', 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,031 __init__.py:126: == Claim: Methane is a potent greenhouse gas.
# [INFO]2025-01-22 08:01:44,031 __init__.py:127: == Evidence: [{'text': 'Methane is a potent greenhouse gas.\nAnswer: Methane is a potent greenhouse gas that has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere. Even though CO2 has a longer-lasting effect, methane sets the pace for warming in the near term.', 'url': 'Google Answer Box'}, {'text': 'Is methane a greenhouse gas?\nAnswer: Methane is also a powerful greenhouse gas. Over a 20-year period, it is 80 times more potent at warming than carbon dioxide. Methane has accounted for roughly 30 per cent of global warming since pre-industrial times and is proliferating faster than at any other time since record keeping began in the 1980s.', 'url': 'Google Answer Box'}, {'text': 'How potent is methane as a greenhouse gas compared to others?\nAnswer: Methane is a potent greenhouse gas that has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere. Even though CO2 has a longer-lasting effect, methane sets the pace for warming in the near term.', 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:44,032 __init__.py:126: == Claim: Cows play a role in climate change.
# [INFO]2025-01-22 08:01:44,033 __init__.py:127: == Evidence: [{'text': 'Cows play a role in climate change.\nAnswer: Cattle are the No. 1 agricultural source of greenhouse gases worldwide. Each year, a single cow will belch about 220 pounds of methane.', 'url': 'Google Answer Box'}, {'text': 'Do cows play a role in climate change? If so, how?\nAnswer: Cow burps are a major contributor to climate change — can scientists change that? Livestock production—primarily cows—produce 14.5 percent of global greenhouse gas emissions. The majority of that is in the form of methane, a potent greenhouse gas that is a natural byproduct of how some livestock process food.', 'url': 'Google Answer Box'}]
#
# [INFO]2025-01-22 08:01:49,645 __init__.py:133: == Claim: Climate change refers to long-term changes in temperature and weather patterns. --- Verify: [Evidence(claim='Climate change refers to long-term changes in temperature and weather patterns.', text='Climate change refers to long-term changes in temperature and weather patterns.\nAnswer: Climate change refers to long-term shifts in temperatures and weather patterns. Human activities have been the main driver of climate change, primarily due to the burning of fossil fuels like coal, oil and gas.', url='Google Answer Box', reasoning='The evidence provided explicitly states that climate change refers to long-term shifts in temperatures and weather patterns. This is in direct agreement with the claim.', relationship='SUPPORTS'), Evidence(claim='Climate change refers to long-term changes in temperature and weather patterns.', text="What does climate change refer to?\nAnswer: Climate change describes a change in the average conditions — such as temperature and rainfall — in a region over a long period of time. NASA scientists have observed Earth's surface is warming, and many of the warmest years on record have happened in the past 20 years.", url='Google Answer Box', reasoning='The evidence explains that climate change refers to changes in average conditions such as temperature and rainfall over a long period of time. This matches the claim that climate change refers to long-term changes in temperature and weather patterns.', relationship='SUPPORTS'), Evidence(claim='Climate change refers to long-term changes in temperature and weather patterns.', text='What types of changes are included in climate change?\nAnswer: Multiple lines of evidence show changes in our weather, oceans, and ecosystems, such as:\n___Changing temperature and precipitation patterns. ...\n___Increases in ocean temperatures, sea level, and acidity. ...\n___Melting of glaciers and sea ice. ...\n___Changes in the frequency, intensity, and duration of extreme weather events.', url='Google Answer Box', reasoning='The evidence confirms that climate change includes changes in weather patterns such as temperature and precipitation, among other long-term changes. Therefore, it supports the claim.', relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,646 __init__.py:133: == Claim: Climate change is primarily caused by human activities like burning fossil fuels and deforestation. --- Verify: [Evidence(claim='Climate change is primarily caused by human activities like burning fossil fuels and deforestation.', text="Climate change is primarily caused by human activities like burning fossil fuels and deforestation.\nAnswer: Burning fossil fuels, cutting down forests and farming livestock are increasingly influencing the climate and the earth's temperature. This adds enormous amounts of greenhouse gases to those naturally occurring in the atmosphere, increasing the greenhouse effect and global warming.", url='Google Answer Box', reasoning='The evidence agrees with the claim that human activities such as burning fossil fuels, cutting down forests, and farming livestock significantly contribute to climate change by increasing greenhouse gases in the atmosphere. This supports the idea that climate change is primarily driven by human activities.', relationship='SUPPORTS'), Evidence(claim='Climate change is primarily caused by human activities like burning fossil fuels and deforestation.', text="What are the primary causes of climate change?\nAnswer: Fossil fuels – coal, oil and gas – are by far the largest contributor to global climate change, accounting for over 75 per cent of global greenhouse gas emissions and nearly 90 per cent of all carbon dioxide emissions. As greenhouse gas emissions blanket the Earth, they trap the sun's heat.", url='Google Answer Box', reasoning='The evidence states that fossil fuels are the largest contributor to global climate change and account for a significant portion of greenhouse gas emissions. This supports the idea that human activities, specifically the burning of fossil fuels, are the primary cause of climate change.', relationship='SUPPORTS'), Evidence(claim='Climate change is primarily caused by human activities like burning fossil fuels and deforestation.', text="How do human activities contribute to climate change?\nAnswer: Burning fossil fuels, cutting down forests and farming livestock are increasingly influencing the climate and the earth's temperature. This adds enormous amounts of greenhouse gases to those naturally occurring in the atmosphere, increasing the greenhouse effect and global warming.", url='Google Answer Box', reasoning='The evidence explains how human activities such as burning fossil fuels, deforestation, and farming livestock increase greenhouse gases in the atmosphere, thereby contributing to the greenhouse effect and global warming. This supports the claim that climate change is primarily caused by human activities.', relationship='SUPPORTS'), Evidence(claim='Climate change is primarily caused by human activities like burning fossil fuels and deforestation.', text='What is the impact of burning fossil fuels on climate change?\nAnswer: What is the link between fossil fuels and climate change? When fossil fuels are burned, they release large amounts of carbon dioxide, a greenhouse gas, into the air. Greenhouse gases trap heat in our atmosphere, causing global warming. Already the average global temperature has increased by 1C.', url='Google Answer Box', reasoning='The evidence explains that burning fossil fuels releases carbon dioxide, a greenhouse gas, which traps heat in the atmosphere and causes global warming. This supports the claim that climate change is primarily caused by human activities like burning fossil fuels.', relationship='SUPPORTS'), Evidence(claim='Climate change is primarily caused by human activities like burning fossil fuels and deforestation.', text="How does deforestation affect climate change?\nAnswer: Trees not only absorb carbon dioxide from our air, they also store carbon in their roots, leaves and trunk. Trees in the Amazon rainforest hold 48 billion tons of carbon. So, when trees are cut down, it's a double whammy on climate change—more carbon dioxide is released an ...
# [INFO]2025-01-22 08:01:49,647 __init__.py:133: == Claim: Burning fossil fuels releases greenhouse gases. --- Verify: [Evidence(claim='Burning fossil fuels releases greenhouse gases.', text='Burning fossil fuels releases greenhouse gases.\nAnswer: When fossil fuels are burned, they release large amounts of carbon dioxide, a greenhouse gas, into the air. Greenhouse gases trap heat in our atmosphere, causing global warming. Already the average global temperature has increased by 1C.', url='Google Answer Box', reasoning='The evidence explains that burning fossil fuels releases large amounts of carbon dioxide, which is a greenhouse gas. This supports the claim that burning fossil fuels releases greenhouse gases.', relationship='SUPPORTS'), Evidence(claim='Burning fossil fuels releases greenhouse gases.', text='What happens when fossil fuels are burned?\nAnswer: When fossil fuels are burned, they release nitrogen oxides into the atmosphere, which contribute to the formation of smog and acid rain. The most common nitrogen-related compounds emitted into the air by human activities are collectively referred to as nitrogen oxides.', url='Google Answer Box', reasoning='The evidence states that burning fossil fuels releases nitrogen oxides into the atmosphere but does not mention greenhouse gases specifically. Therefore, while related, it does not directly support the claim that burning fossil fuels releases greenhouse gases.', relationship='IRRELEVANT'), Evidence(claim='Burning fossil fuels releases greenhouse gases.', text='Do burning fossil fuels release greenhouse gases?\nAnswer: Human activities are responsible for almost all of the increase in greenhouse gases in the atmosphere over the last 150 years. The largest source of greenhouse gas emissions from human activities in the United States is from burning fossil fuels for electricity, heat, and transportation.', url='Google Answer Box', reasoning='The evidence provided states that the largest source of greenhouse gas emissions from human activities in the United States is from burning fossil fuels for electricity, heat, and transportation. This confirms that burning fossil fuels releases greenhouse gases, supporting the claim.', relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,648 __init__.py:133: == Claim: Deforestation releases greenhouse gases. --- Verify: [Evidence(claim='Deforestation releases greenhouse gases.', text='Deforestation releases greenhouse gases.\nAnswer: When deforestation occurs, much of the carbon stored by trees\ufeff is released back into the atmosphere as carbon dioxide, which contributes to climate change\ufeff.', url='Google Answer Box', reasoning='The evidence confirms that deforestation releases the greenhouse gas carbon dioxide back into the atmosphere, which contributes to climate change. Therefore, it supports the claim that deforestation releases greenhouse gases.', relationship='SUPPORTS'), Evidence(claim='Deforestation releases greenhouse gases.', text='Does deforestation release greenhouse gases?\nAnswer: If forests are cleared, or even disturbed, they release carbon dioxide and other greenhouse gases. Forest loss and damage is the cause of around 10% of global warming.', url='Google Answer Box', reasoning='The evidence directly addresses the question of whether deforestation releases greenhouse gases, stating that clearing or disturbing forests releases carbon dioxide and other greenhouse gases. It also mentions that forest loss and damage contribute to global warming. This supports the claim that deforestation releases greenhouse gases.', relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,649 __init__.py:133: == Claim: Greenhouse gases trap heat in the atmosphere. --- Verify: [Evidence(claim='Greenhouse gases trap heat in the atmosphere.', text='Greenhouse gases trap heat in the atmosphere.\nAnswer: The greenhouse effect works much the same way on Earth. Gases in the atmosphere, such as carbon dioxide, trap heat similar to the glass roof of a greenhouse. These heat-trapping gases are called greenhouse gases. During the day, the Sun shines through the atmosphere.', url='Google Answer Box', reasoning='The evidence explains that greenhouse gases, such as carbon dioxide, trap heat in the atmosphere similarly to the glass roof of a greenhouse. This confirms the claim that greenhouse gases trap heat in the atmosphere.', relationship='SUPPORTS'), Evidence(claim='Greenhouse gases trap heat in the atmosphere.', text="What do greenhouse gases do?\nAnswer: Greenhouse gases act similarly to the glass in a greenhouse: they absorb the sun's heat that radiates from the Earth's surface, trap it in the atmosphere and prevent it from escaping into space. The greenhouse effect keeps the Earth's temperature warmer than it would otherwise be, supporting life on Earth.", url='Google Answer Box', reasoning="The evidence explains that greenhouse gases trap heat in the atmosphere by absorbing the sun's heat radiating from the Earth's surface and preventing it from escaping into space. This supports the claim that greenhouse gases trap heat in the atmosphere.", relationship='SUPPORTS'), Evidence(claim='Greenhouse gases trap heat in the atmosphere.', text="Where do greenhouse gases trap heat?\nAnswer: Earth's greenhouse gases trap heat in the atmosphere and warm the planet. The main gases responsible for the greenhouse effect include carbon dioxide, methane, nitrous oxide, and water vapor.", url='Google Answer Box', reasoning="The evidence clearly states that Earth's greenhouse gases trap heat in the atmosphere and warm the planet, confirming that greenhouse gases do indeed trap heat in the atmosphere. This directly supports the claim.", relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,649 __init__.py:133: == Claim: Cows produce methane during digestion. --- Verify: [Evidence(claim='Cows produce methane during digestion.', text='Cows produce methane during digestion.\nAnswer: Methane is the main greenhouse gas produced in grazing systems. Ruminant livestock (cattle, sheep, and goats) have microbes in their rumen called methanogens. These microbes produce methane (from the fermentation of feed) that is then belched out.', url='Google Answer Box', reasoning='The evidence explains that ruminant livestock like cows have microbes in their rumen that produce methane during feed fermentation, which is then belched out. This confirms that cows produce methane during digestion.', relationship='SUPPORTS'), Evidence(claim='Cows produce methane during digestion.', text='Do cows produce methane during digestion?\nAnswer: Methane emissions from the digestive processes in ruminant animals, including cattle, sheep and wild animals, is estimated to provide an atmospheric source of 87-94 Tg (a million million grams) per year. Methane emissions depend upon the number and type of animals and the type of food.', url='Google Answer Box', reasoning='The evidence confirms that methane emissions are produced from the digestive processes in ruminant animals, including cattle. This directly supports the claim that cows produce methane during digestion.', relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,650 __init__.py:133: == Claim: Methane is a potent greenhouse gas. --- Verify: [Evidence(claim='Methane is a potent greenhouse gas.', text='Methane is a potent greenhouse gas.\nAnswer: Methane is a potent greenhouse gas that has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere. Even though CO2 has a longer-lasting effect, methane sets the pace for warming in the near term.', url='Google Answer Box', reasoning='The evidence confirms that methane is a potent greenhouse gas with significant warming effects, specifically stating its high warming power relative to carbon dioxide over a 20-year period. This directly supports the claim.', relationship='SUPPORTS'), Evidence(claim='Methane is a potent greenhouse gas.', text='Is methane a greenhouse gas?\nAnswer: Methane is also a powerful greenhouse gas. Over a 20-year period, it is 80 times more potent at warming than carbon dioxide. Methane has accounted for roughly 30 per cent of global warming since pre-industrial times and is proliferating faster than at any other time since record keeping began in the 1980s.', url='Google Answer Box', reasoning="The evidence provided clearly states that methane is a powerful greenhouse gas and is significantly more potent at warming than carbon dioxide over a 20-year period. This supports the claim by explaining methane's role in global warming and providing specific details about its potency and historical impact.", relationship='SUPPORTS'), Evidence(claim='Methane is a potent greenhouse gas.', text='How potent is methane as a greenhouse gas compared to others?\nAnswer: Methane is a potent greenhouse gas that has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere. Even though CO2 has a longer-lasting effect, methane sets the pace for warming in the near term.', url='Google Answer Box', reasoning='The evidence states that methane has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere, establishing its potency as a greenhouse gas. This confirms the claim that methane is a potent greenhouse gas.', relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,651 __init__.py:133: == Claim: Cows play a role in climate change. --- Verify: [Evidence(claim='Cows play a role in climate change.', text='Cows play a role in climate change.\nAnswer: Cattle are the No. 1 agricultural source of greenhouse gases worldwide. Each year, a single cow will belch about 220 pounds of methane.', url='Google Answer Box', reasoning='The evidence states that cattle are the top agricultural source of greenhouse gases globally and that each cow produces a significant amount of methane. This implies that cows contribute to climate change through their greenhouse gas emissions.', relationship='SUPPORTS'), Evidence(claim='Cows play a role in climate change.', text='Do cows play a role in climate change? If so, how?\nAnswer: Cow burps are a major contributor to climate change — can scientists change that? Livestock production—primarily cows—produce 14.5 percent of global greenhouse gas emissions. The majority of that is in the form of methane, a potent greenhouse gas that is a natural byproduct of how some livestock process food.', url='Google Answer Box', reasoning='The evidence indicates that cows contribute significantly to global greenhouse gas emissions, particularly methane, which is a potent contributor to climate change. This supports the claim that cows play a role in climate change.', relationship='SUPPORTS')]
# [INFO]2025-01-22 08:01:49,654 __init__.py:135: == State: Done!
#  Total time: 20.98s. (create claims:13.42s |||  retrieve:1.93s ||| verify:5.62s)
# [INFO]2025-01-22 08:01:49,655 __init__.py:234: == Overall Factuality: 1.0

# %%
results.keys()
# Out:
# dict_keys(['raw_text', 'token_count', 'usage', 'claim_detail', 'summary'])

# %%
results['summary']
# Out:
# {'num_claims': 8,
#  'num_checkworthy_claims': 8,
#  'num_verified_claims': 8,
#  'num_supported_claims': 8,
#  'num_refuted_claims': 0,
#  'num_controversial_claims': 0,
#  'factuality': 1.0}

# %%
results['claim_detail']
# Out:
# [{'id': 0,
#   'claim': 'Climate change refers to long-term changes in temperature and weather patterns.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the definition of climate change.)',
#   'origin_text': 'Climate change refers to long-term changes in temperature and weather patterns,',
#   'start': 0,
#   'end': 79,
#   'queries': ['Climate change refers to long-term changes in temperature and weather patterns.',
#    'What does climate change refer to?',
#    'What types of changes are included in climate change?'],
#   'evidences': [{'claim': 'Climate change refers to long-term changes in temperature and weather patterns.',
#     'text': 'Climate change refers to long-term changes in temperature and weather patterns.\nAnswer: Climate change refers to long-term shifts in temperatures and weather patterns. Human activities have been the main driver of climate change, primarily due to the burning of fossil fuels like coal, oil and gas.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence provided explicitly states that climate change refers to long-term shifts in temperatures and weather patterns. This is in direct agreement with the claim.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Climate change refers to long-term changes in temperature and weather patterns.',
#     'text': "What does climate change refer to?\nAnswer: Climate change describes a change in the average conditions — such as temperature and rainfall — in a region over a long period of time. NASA scientists have observed Earth's surface is warming, and many of the warmest years on record have happened in the past 20 years.",
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains that climate change refers to changes in average conditions such as temperature and rainfall over a long period of time. This matches the claim that climate change refers to long-term changes in temperature and weather patterns.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Climate change refers to long-term changes in temperature and weather patterns.',
#     'text': 'What types of changes are included in climate change?\nAnswer: Multiple lines of evidence show changes in our weather, oceans, and ecosystems, such as:\n___Changing temperature and precipitation patterns. ...\n___Increases in ocean temperatures, sea level, and acidity. ...\n___Melting of glaciers and sea ice. ...\n___Changes in the frequency, intensity, and duration of extreme weather events.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence confirms that climate change includes changes in weather patterns such as temperature and precipitation, among other long-term changes. Therefore, it supports the claim.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 1,
#   'claim': 'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the causes of climate change.)',
#   'origin_text': 'primarily caused by human activities like burning fossil fuels and deforestation.',
#   'start': 80,
#   'end': 161,
#   'queries': ['Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#    'What are the primary causes of climate change?',
#    'How do human activities contribute to climate change?',
#    'What is the impact of burning fossil fuels on climate change?',
#    'How does deforestation affect climate change?'],
#   'evidences': [{'claim': 'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#     'text': "Climate change is primarily caused by human activities like burning fossil fuels and deforestation.\nAnswer: Burning fossil fuels, cutting down forests and farming livestock are increasingly influencing the climate and the earth's temperature. This adds enormous amounts of greenhouse gases to those naturally occurring in the atmosphere, increasing the greenhouse effect and global warming.",
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence agrees with the claim that human activities such as burning fossil fuels, cutting down forests, and farming livestock significantly contribute to climate change by increasing greenhouse gases in the atmosphere. This supports the idea that climate change is primarily driven by human activities.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#     'text': "What are the primary causes of climate change?\nAnswer: Fossil fuels – coal, oil and gas – are by far the largest contributor to global climate change, accounting for over 75 per cent of global greenhouse gas emissions and nearly 90 per cent of all carbon dioxide emissions. As greenhouse gas emissions blanket the Earth, they trap the sun's heat.",
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence states that fossil fuels are the largest contributor to global climate change and account for a significant portion of greenhouse gas emissions. This supports the idea that human activities, specifically the burning of fossil fuels, are the primary cause of climate change.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#     'text': "How do human activities contribute to climate change?\nAnswer: Burning fossil fuels, cutting down forests and farming livestock are increasingly influencing the climate and the earth's temperature. This adds enormous amounts of greenhouse gases to those naturally occurring in the atmosphere, increasing the greenhouse effect and global warming.",
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains how human activities such as burning fossil fuels, deforestation, and farming livestock increase greenhouse gases in the atmosphere, thereby contributing to the greenhouse effect and global warming. This supports the claim that climate change is primarily caused by human activities.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#     'text': 'What is the impact of burning fossil fuels on climate change?\nAnswer: What is the link between fossil fuels and climate change? When fossil fuels are burned, they release large amounts of carbon dioxide, a greenhouse gas, into the air. Greenhouse gases trap heat in our atmosphere, causing global warming. Already the average global temperature has increased by 1C.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains that burning fossil fuels releases carbon dioxide, a greenhouse gas, which traps heat in the atmosphere and causes global warming. This supports the claim that climate change is primarily caused by human activities like burning fossil fuels.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Climate change is primarily caused by human activities like burning fossil fuels and deforestation.',
#     'text': "How does deforestation affect climate change?\nAnswer: Trees not only absorb carbon dioxide from our air, they also store carbon in their roots, leaves and trunk. Trees in the Amazon rainforest hold 48 billion tons of carbon. So, when trees are cut down, it's a double whammy on climate change—more carbon dioxide is released and less is absorbed.",
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains how deforestation contributes to climate change by releasing stored carbon dioxide when trees are cut down and reducing the amount of carbon dioxide that is absorbed. This supports the claim that human activities like deforestation contribute to climate change.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 2,
#   'claim': 'Burning fossil fuels releases greenhouse gases.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the release of greenhouse gases from burning fossil fuels.)',
#   'origin_text': 'These actions release greenhouse gases,',
#   'start': 162,
#   'end': 201,
#   'queries': ['Burning fossil fuels releases greenhouse gases.',
#    'What happens when fossil fuels are burned?',
#    'Do burning fossil fuels release greenhouse gases?'],
#   'evidences': [{'claim': 'Burning fossil fuels releases greenhouse gases.',
#     'text': 'Burning fossil fuels releases greenhouse gases.\nAnswer: When fossil fuels are burned, they release large amounts of carbon dioxide, a greenhouse gas, into the air. Greenhouse gases trap heat in our atmosphere, causing global warming. Already the average global temperature has increased by 1C.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains that burning fossil fuels releases large amounts of carbon dioxide, which is a greenhouse gas. This supports the claim that burning fossil fuels releases greenhouse gases.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Burning fossil fuels releases greenhouse gases.',
#     'text': 'What happens when fossil fuels are burned?\nAnswer: When fossil fuels are burned, they release nitrogen oxides into the atmosphere, which contribute to the formation of smog and acid rain. The most common nitrogen-related compounds emitted into the air by human activities are collectively referred to as nitrogen oxides.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence states that burning fossil fuels releases nitrogen oxides into the atmosphere but does not mention greenhouse gases specifically. Therefore, while related, it does not directly support the claim that burning fossil fuels releases greenhouse gases.',
#     'relationship': 'IRRELEVANT'},
#    {'claim': 'Burning fossil fuels releases greenhouse gases.',
#     'text': 'Do burning fossil fuels release greenhouse gases?\nAnswer: Human activities are responsible for almost all of the increase in greenhouse gases in the atmosphere over the last 150 years. The largest source of greenhouse gas emissions from human activities in the United States is from burning fossil fuels for electricity, heat, and transportation.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence provided states that the largest source of greenhouse gas emissions from human activities in the United States is from burning fossil fuels for electricity, heat, and transportation. This confirms that burning fossil fuels releases greenhouse gases, supporting the claim.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 3,
#   'claim': 'Deforestation releases greenhouse gases.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the release of greenhouse gases from deforestation.)',
#   'origin_text': '',
#   'start': 201,
#   'end': 201,
#   'queries': ['Deforestation releases greenhouse gases.',
#    'Does deforestation release greenhouse gases?'],
#   'evidences': [{'claim': 'Deforestation releases greenhouse gases.',
#     'text': 'Deforestation releases greenhouse gases.\nAnswer: When deforestation occurs, much of the carbon stored by trees\ufeff is released back into the atmosphere as carbon dioxide, which contributes to climate change\ufeff.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence confirms that deforestation releases the greenhouse gas carbon dioxide back into the atmosphere, which contributes to climate change. Therefore, it supports the claim that deforestation releases greenhouse gases.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Deforestation releases greenhouse gases.',
#     'text': 'Does deforestation release greenhouse gases?\nAnswer: If forests are cleared, or even disturbed, they release carbon dioxide and other greenhouse gases. Forest loss and damage is the cause of around 10% of global warming.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence directly addresses the question of whether deforestation releases greenhouse gases, stating that clearing or disturbing forests releases carbon dioxide and other greenhouse gases. It also mentions that forest loss and damage contribute to global warming. This supports the claim that deforestation releases greenhouse gases.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 4,
#   'claim': 'Greenhouse gases trap heat in the atmosphere.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the effect of greenhouse gases.)',
#   'origin_text': 'which trap heat in the atmosphere.',
#   'start': 202,
#   'end': 236,
#   'queries': ['Greenhouse gases trap heat in the atmosphere.',
#    'What do greenhouse gases do?',
#    'Where do greenhouse gases trap heat?'],
#   'evidences': [{'claim': 'Greenhouse gases trap heat in the atmosphere.',
#     'text': 'Greenhouse gases trap heat in the atmosphere.\nAnswer: The greenhouse effect works much the same way on Earth. Gases in the atmosphere, such as carbon dioxide, trap heat similar to the glass roof of a greenhouse. These heat-trapping gases are called greenhouse gases. During the day, the Sun shines through the atmosphere.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains that greenhouse gases, such as carbon dioxide, trap heat in the atmosphere similarly to the glass roof of a greenhouse. This confirms the claim that greenhouse gases trap heat in the atmosphere.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Greenhouse gases trap heat in the atmosphere.',
#     'text': "What do greenhouse gases do?\nAnswer: Greenhouse gases act similarly to the glass in a greenhouse: they absorb the sun's heat that radiates from the Earth's surface, trap it in the atmosphere and prevent it from escaping into space. The greenhouse effect keeps the Earth's temperature warmer than it would otherwise be, supporting life on Earth.",
#     'url': 'Google Answer Box',
#     'reasoning': "The evidence explains that greenhouse gases trap heat in the atmosphere by absorbing the sun's heat radiating from the Earth's surface and preventing it from escaping into space. This supports the claim that greenhouse gases trap heat in the atmosphere.",
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Greenhouse gases trap heat in the atmosphere.',
#     'text': "Where do greenhouse gases trap heat?\nAnswer: Earth's greenhouse gases trap heat in the atmosphere and warm the planet. The main gases responsible for the greenhouse effect include carbon dioxide, methane, nitrous oxide, and water vapor.",
#     'url': 'Google Answer Box',
#     'reasoning': "The evidence clearly states that Earth's greenhouse gases trap heat in the atmosphere and warm the planet, confirming that greenhouse gases do indeed trap heat in the atmosphere. This directly supports the claim.",
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 5,
#   'claim': 'Cows produce methane during digestion.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about cows producing methane.)',
#   'origin_text': 'As for cows, they produce methane, a potent greenhouse gas, during digestion.',
#   'start': 237,
#   'end': 314,
#   'queries': ['Cows produce methane during digestion.',
#    'Do cows produce methane during digestion?'],
#   'evidences': [{'claim': 'Cows produce methane during digestion.',
#     'text': 'Cows produce methane during digestion.\nAnswer: Methane is the main greenhouse gas produced in grazing systems. Ruminant livestock (cattle, sheep, and goats) have microbes in their rumen called methanogens. These microbes produce methane (from the fermentation of feed) that is then belched out.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence explains that ruminant livestock like cows have microbes in their rumen that produce methane during feed fermentation, which is then belched out. This confirms that cows produce methane during digestion.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Cows produce methane during digestion.',
#     'text': 'Do cows produce methane during digestion?\nAnswer: Methane emissions from the digestive processes in ruminant animals, including cattle, sheep and wild animals, is estimated to provide an atmospheric source of 87-94 Tg (a million million grams) per year. Methane emissions depend upon the number and type of animals and the type of food.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence confirms that methane emissions are produced from the digestive processes in ruminant animals, including cattle. This directly supports the claim that cows produce methane during digestion.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 6,
#   'claim': 'Methane is a potent greenhouse gas.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the potency of methane as a greenhouse gas.)',
#   'origin_text': '',
#   'start': 314,
#   'end': 314,
#   'queries': ['Methane is a potent greenhouse gas.',
#    'Is methane a greenhouse gas?',
#    'How potent is methane as a greenhouse gas compared to others?'],
#   'evidences': [{'claim': 'Methane is a potent greenhouse gas.',
#     'text': 'Methane is a potent greenhouse gas.\nAnswer: Methane is a potent greenhouse gas that has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere. Even though CO2 has a longer-lasting effect, methane sets the pace for warming in the near term.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence confirms that methane is a potent greenhouse gas with significant warming effects, specifically stating its high warming power relative to carbon dioxide over a 20-year period. This directly supports the claim.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Methane is a potent greenhouse gas.',
#     'text': 'Is methane a greenhouse gas?\nAnswer: Methane is also a powerful greenhouse gas. Over a 20-year period, it is 80 times more potent at warming than carbon dioxide. Methane has accounted for roughly 30 per cent of global warming since pre-industrial times and is proliferating faster than at any other time since record keeping began in the 1980s.',
#     'url': 'Google Answer Box',
#     'reasoning': "The evidence provided clearly states that methane is a powerful greenhouse gas and is significantly more potent at warming than carbon dioxide over a 20-year period. This supports the claim by explaining methane's role in global warming and providing specific details about its potency and historical impact.",
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Methane is a potent greenhouse gas.',
#     'text': 'How potent is methane as a greenhouse gas compared to others?\nAnswer: Methane is a potent greenhouse gas that has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere. Even though CO2 has a longer-lasting effect, methane sets the pace for warming in the near term.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence states that methane has more than 80 times the warming power of carbon dioxide over the first 20 years after it reaches the atmosphere, establishing its potency as a greenhouse gas. This confirms the claim that methane is a potent greenhouse gas.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0},
#  {'id': 7,
#   'claim': 'Cows play a role in climate change.',
#   'checkworthy': True,
#   'checkworthy_reason': 'Yes (The statement contains verifiable factual information about the role of cows in impacting climate change through methane production.)',
#   'origin_text': "So, while they can't literally talk, they do play a role in climate change!",
#   'start': 315,
#   'end': 390,
#   'queries': ['Cows play a role in climate change.',
#    'Do cows play a role in climate change? If so, how?'],
#   'evidences': [{'claim': 'Cows play a role in climate change.',
#     'text': 'Cows play a role in climate change.\nAnswer: Cattle are the No. 1 agricultural source of greenhouse gases worldwide. Each year, a single cow will belch about 220 pounds of methane.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence states that cattle are the top agricultural source of greenhouse gases globally and that each cow produces a significant amount of methane. This implies that cows contribute to climate change through their greenhouse gas emissions.',
#     'relationship': 'SUPPORTS'},
#    {'claim': 'Cows play a role in climate change.',
#     'text': 'Do cows play a role in climate change? If so, how?\nAnswer: Cow burps are a major contributor to climate change — can scientists change that? Livestock production—primarily cows—produce 14.5 percent of global greenhouse gas emissions. The majority of that is in the form of methane, a potent greenhouse gas that is a natural byproduct of how some livestock process food.',
#     'url': 'Google Answer Box',
#     'reasoning': 'The evidence indicates that cows contribute significantly to global greenhouse gas emissions, particularly methane, which is a potent contributor to climate change. This supports the claim that cows play a role in climate change.',
#     'relationship': 'SUPPORTS'}],
#   'factuality': 1.0}]
