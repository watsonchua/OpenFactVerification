# %%
import sys
sys.path.append("/home/watso/OpenFactVerification")
import nest_asyncio
nest_asyncio.apply()

# %%
from factcheck import FactCheck

# %%
from factcheck.utils.utils import load_yaml
api_config_path="/home/watso/OpenFactVerification/api_config.yaml"
api_config = load_yaml(api_config_path)


factcheck_instance = FactCheck(
        default_model="gpt-4o-eastus", client=None, api_config=api_config, prompt="chatgpt_prompt", retriever="serper"
    )
# Out:
# [INFO]2025-01-22 04:00:41,366 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 04:00:41,374 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 04:00:41,381 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 04:00:41,387 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 04:00:41,393 __init__.py:61: == LLMClient is not specified, use default llm client.
# [INFO]2025-01-22 04:00:41,400 __init__.py:76: ===Sub-modules Init Finished===
# == Init decompose_model with model: gpt-4o-eastus
# == Init checkworthy_model with model: gpt-4o-eastus
# == Init query_generator_model with model: gpt-4o-eastus
# == Init evidence_retrieval_model with model: gpt-4o-eastus
# == Init claim_verify_model with model: gpt-4o-eastus

# %%
# Example text
text = "Climate change refers to long-term changes in temperature and weather patterns, primarily caused by human activities like burning fossil fuels and deforestation. These actions release greenhouse gases, which trap heat in the atmosphere. As for cows, they produce methane, a potent greenhouse gas, during digestion. So, while they can't literally talk, they do play a role in climate change!"

# Run the fact-check pipeline
results = factcheck_instance.check_text(text)
print(results)
# Out:
# [ERROR]2025-01-22 04:00:47,782 Decompose.py:135: Parse LLM response error Restore claims not satisfied., response is: {
#   "Climate change refers to long-term changes in temperature.": "Climate change refers to long-term changes in temperature",
#   "Climate change refers to long-term changes in weather patterns.": "and weather patterns,",
#   "Climate change is primarily caused by human activities like burning fossil fuels.": "primarily caused by human activities like burning fossil fuels",
#   "Climate change is primarily caused by deforestation.": "and deforestation.",
#   "Burning fossil fuels releases greenhouse gases.": "These actions release greenhouse gases,",
#   "Deforestation releases greenhouse gases.": "These actions release greenhouse gases,",
#   "Greenhouse gases trap heat in the atmosphere.": "which trap heat in the atmosphere.",
#   "Cows produce methane during digestion.": "As for cows, they produce methane, a potent greenhouse gas, during digestion.",
# ...

# %%
results
# Out:
# {'raw_text': "Climate change refers to long-term changes in temperature and weather patterns, primarily caused by human activities like burning fossil fuels and deforestation. These actions release greenhouse gases, which trap heat in the atmosphere. As for cows, they produce methane, a potent greenhouse gas, during digestion. So, while they can't literally talk, they do play a role in climate change!",
#  'token_count': 73,
#  'usage': {'decomposer': {'model': 'gpt-4o-eastus',
#    'prompt_tokens': 1421,
#    'completion_tokens': 800},
#   'checkworthy': {'model': 'gpt-4o-eastus',
#    'prompt_tokens': 481,
#    'completion_tokens': 365},
#   'query_generator': {'model': 'gpt-4o-eastus',
#    'prompt_tokens': 3280,
#    'completion_tokens': 264},
#   'evidence_crawler': {'model': 'gpt-4o-eastus',
#    'prompt_tokens': 0,
#    'completion_tokens': 0},
#   'claimverify': {'model': 'gpt-4o-eastus',
#    'prompt_tokens': 14974,
#    'completion_tokens': 1638}},
# ...
